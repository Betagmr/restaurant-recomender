# %%
from src.utils import load_all_restaurants
from src.processing.extract_features import *
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiewu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiewu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = load_all_restaurants("data\\raw")
df.head()
# Out:
#                        title  \
# 0         Restaurante Abando
# 1  Bar-Restaurante "La Roca"
# 2          La Gavilla Bilbao
# 3           La Kedada Bilbao
# 4         Restaurante Aralar
#
#                                          description  n_reviews stars_avg  \
# 0  Restaurante de larga trayectoria con pinchos c...       3000       4,3
# 1                                                NaN      11000       4,2
# 2  Restaurante funcional y acogedor que ofrece pl...      11000       4,5
# 3  Bar restaurante de un hotel moderno y de pared...         54       4,0
# 4                                                NaN        883       4,3
#
#   price_range                                     extra_features  \
# 0          €€  Tiene terraza· Tiene Wi-Fi· Sillas altas dispo...
# 1      20-30€  Ideal para ver deportes· Sillas altas disponib...
# 2      30-40€                                                NaN
# 3         NaN  Tiene terraza· Tiene comedor privado· Tiene Wi-Fi
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
direcciones = obtener_lat_long()
df = asignar_valor_por_cp(df, direcciones)
palabras, df = procesar_y_graficar(df, 'TD', 30)
df = tipo_establecimiento_direccion(df)

# %%
palabras
# Out:
# [('bar', 298),
#  ('restaurante', 272),
#  ('bilbao', 104),
#  ('cocina', 59),
#  ('platos', 58),
#  ('taberna', 53),
#  ('cafe', 41),
#  ('vasca', 39),
#  ('pintxos', 35),
#  ('pinchos', 32),
#  ('vinos', 31),
#  ('sirve', 30),
#  ('barra', 30),
#  ('terraza', 29),
#  ('hamburguesas', 28),
#  ('moderno', 27),
#  ('tapas', 27),
#  ('cafeteria', 27),
#  ('comedor', 19),
#  ('menu', 19),
#  ('estilo', 18),
#  ('paredes', 17),
#  ('berria', 17),
#  ('comida', 16),
#  ('acogedor', 16),
#  ('vino', 16),
#  ('madera', 16),
#  ('informal', 16),
#  ('decoracion', 16),
#  ('cerveza', 14)]

# %%
df.columns
# Out:
# Index(['title', 'description', 'n_reviews', 'stars_avg', 'price_range',
#        'extra_features', 'street', 'opening_hours', 'phone_number', 'reviews',
#        'extra_content', 'unique_id', 'Centro', 'Este', 'Norte', 'Oeste', 'Sur',
#        'bar', 'cafe', 'hamburguesa', 'otros', 'restaurante', 'taberna'],
#       dtype='object')
